# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
import os
os.chdir('/gdrive/My Drive')

# %%
import pandas as pd
df = pd.read_csv('Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.Salary.unique()
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872])

# %%
df.Salary.value_counts()
# Out:
# Salary
# 39343     1
# 46205     1
# 122391    1
# 112635    1
# 116969    1
# 105582    1
# 109431    1
# 113812    1
# 101302    1
# 98273     1
# 91738     1
# 93940     1
# 81363     1
# 83088     1
# 66029     1
# 67938     1
# 61111     1
# 57081     1
# 56957     1
# 55794     1
# 63218     1
# 57189     1
# 64445     1
# 54445     1
# 60150     1
# 56642     1
# 39891     1
# 43525     1
# 37731     1
# 121872    1
# Name: count, dtype: int64

# %%
df.YearsExperience.value_counts()
# Out:
# YearsExperience
# 3.2     2
# 4.0     2
# 1.1     1
# 5.3     1
# 10.3    1
# 9.6     1
# 9.5     1
# 9.0     1
# 8.7     1
# 8.2     1
# 7.9     1
# 7.1     1
# 6.8     1
# 6.0     1
# 5.9     1
# 5.1     1
# 1.3     1
# 4.9     1
# 4.5     1
# 4.1     1
# 3.9     1
# 3.7     1
# 3.0     1
# 2.9     1
# 2.2     1
# 2.0     1
# 1.5     1
# 10.5    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(y='YearsExperience',x='Salary',data=df)
plt.show()

# %%
sns.boxplot(x='YearsExperience',y='Salary',data=df)
plt.show()

# %%
sns.catplot(x='YearsExperience',y='Salary',data=df,kind='box');

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd

# Replace 'Salary_Data.csv' with the actual path to your CSV file
df = pd.read_csv('Salary_Data.csv')

# Example usage of numpy with the dataframe
# Calculate the mean of a column named 'column_name'
mean_value = np.mean(df['Salary'])
print(f"The mean of the column is: {mean_value}")


# Or convert a column to a numpy array
column_as_array = df['Salary'].to_numpy()
print(column_as_array)
# Out:
# The mean of the column is: 76003.0
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]
